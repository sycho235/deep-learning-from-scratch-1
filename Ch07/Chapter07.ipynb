# %% [markdown]
# # Chapter 7 합성곱 신경망(CNN)

# %% [markdown]
# ## 7.1 전체 구조
# P.227

# %% [markdown]
# < 완전연결 계층(Affine 계층)으로 이뤄진 네트워크의 예 >
# <img src='./img/fig 7-1.png' width=650>
#
# <br>
#
# < CNN으로 이뤄진 네트워크의 예 >
# <img src='./img/fig 7-2.png' width=650>

# %% [markdown]
# ## 7.2 합성곱 계층
# P.229

# %% [markdown]
# ### 7.2.1 완전연결 계층의 문제점
#
# __완전연결 계층__
# - 데이터의 형상이 무시됨 (3차원 데이터 $\rightarrow$ 1차원 데이터)
#
# __합성곱 계층__
# - 형상을 유지 (3차원 데이터로 입력 및 전달)
# - __특징 맵__ : 합성곱 계층의 입출력 데이터
#     - 입력 특징 맵 : 입력 데이터
#     - 출력 특징 맵 : 출력 데이터

# %% [markdown]
# ### 7.2.2 합성곱 연산
#
# __합성곱 연산(필터 연산)__
# <img src='./img/fig 7-3.png' width=500>
#
# - __필터(커널)__
#
#
# <img src='./img/fig 7-4.png' width=500>
#
# - 필터의 윈도우를 일정 간격으로 이동해가며 입력 데이터에 적용
# - 입력과 필터에서 대응하는 원소끼리 곱한 후 그 총합을 구함
# - 결과를 출력의 해당 장소에 저장
#
#
# <img src='./img/fig 7-5.png' width=600>
#
# - 가중치 : 필터의 매개변수
# - 편향
#     - 필터를 적용한 후의 데이터에 더해짐.
#     - 항상 하나(1 $\times$ 1)만 존재

# %% [markdown]
# ### 7.2.3 패딩
#
# __패딩__ : 합성곱 연산을 수행하기 전에 입력 데이터 주변을 특정 값(예컨대 0)으로 채우기
#
# <img src='./img/fig 7-6.png' width=500>
#
#
# ※ NOTE_
#
# 패딩은 주로 __출력의 크기를 조정__할 목적으로 사용함.
# - 합성곱 연산을 거칠 때마다 크기가 작아지면 어느 시점에서는 출력 크기가 1이 됨
# - 패딩을 이용해서 입력 데이터의 공간적 크기를 고정한 채로 다음 계층에 전달할 수 있음

# %% [markdown]
# ### 7.2.4 스트라이드
#
# __스트라이드__ : 필터를 적용하는 위치의 간격
# - 스트라이드 = 2 : 윈도우가 두 칸씩 이동
#
# <img src='./img/fig 7-7.png' width=500>
#
# <br>
#
# __패딩, 스트라이드, 출력 크기의 관계__
#
# $$OH = \frac{H + 2P - FH}{S} + 1$$
#
# $$OW = \frac{W + 2P - FW}{S} + 1$$
#
# - 입력 크기 : (H, W) / 필터 크기 : (FH, FW) / 출력 크기 : (OH, OW)
# - 패딩 : P / 스트라이드 : S
#     - 스트라이드를 키우면 출력의 크기는 작아짐.
#     - 패딩을 크게 하면 출력 크기가 커짐.
# - 출력 크기는 __정수__로 나눠떨어지는 값이어야 함.

# %% [markdown]
# ### 7.2.5 3차원 데이터의 합성곱 연산
#
# <img src='./img/fig 7-8.png' width=500>
#
# - 입력 데이터와 필터의 합성곱 연산을 채널마다 수행
# - 그 결과를 더해서 하나의 출력을 얻음
#
#
# <img src='./img/fig 7-9.png' width=500>
#
# __주의!__
# - 입력 데이터의 채널 수와 필터의 채널 수가 같아야 함
#
#     (필터 자체의 크기는 원하는 값으로 설정해도 됨)

# %% [markdown]
# ### 7.2.6 블록으로 생각하기
#
# < 채널이 1개인 출력 데이터 >
# <img src='./img/fig 7-10.png' width=500>
#
# <br>
#
# < 채널이 FN개인 출력 데이터 >
# <img src='./img/fig 7-11.png' width=500>
#
# <br>
#
# < 편향 추가 >
# <img src='./img/fig 7-12.png' width=600>
#
# - 형상이 다른 블록의 덧셈은 넘파이의 브로드캐스트 기능으로 구현

# %% [markdown]
# ### 7.2.7 배치 처리
#
# < 데이터가 N개일 때 >
# <img src='./img/fig 7-13.png' width=600>
#
# - 신경망에 4차원 데이터가 하나 흐를 때마다 데이터 N개에 대한 합성곱 연산이 이뤄짐

# %% [markdown]
# ## 7.3 풀링 계층
# P.240

# %% [markdown]
# __풀링__ : 세로 $\cdot$ 가로 방향의 공간을 줄이는 연산
#
# < 2 $\times$ 2 최대 풀링을 스트라이드 2로 처리하는 순서 >
# <img src='./img/fig 7-14.png' width=600>
#
# - __최대 풀링__ : 대상 영역에서 최댓값을 구함
# - 풀링의 윈도우 크가와 스트라이드는 같은 값으로 설정하는 것이 보통임

# %% [markdown]
# ※ WARNING_
#
# __평균 풀링__ : 대상 영역의 평균을 계산
#
# >이미지 인식 분야에서는 주로 __최대 풀링__을 사용

# %% [markdown]
# ### 7.3.1 풀링 계층의 특징
#
# #### 학습해야 할 매개변수가 없다
#
#     대상 영역에서 최댓값이나 평균을 취하는 명확한 처리
#
#
# #### 채널 수가 변하지 않는다
#
#     채널마다 독립적으로 계산하기 때문
#
# <img src='./img/fig 7-15.png' width=400>
#
#
# #### 입력의 변화에 영향을 적게 받는다(강건하다)
#
#     입력 데이터의 차이를 풀링이 흡수해 사라지게 함 (데이터에 따라 다를 수 있음)
#
# <img src='./img/fig 7-16.png' width=500>

# %% [markdown]
# ## 7.4 합성곱/풀링 계층 구현하기
# P. 242

# %% [markdown]
# ### 7.4.1 4차원 배열

# %%
import numpy as np

# 4차원 데이터 - (데이터 수, 채널 수, 높이, 너비)
x = np.random.rand(10, 1, 28, 28)  # 무작위로 데이터 생성
x.shape
# Out:
# (10, 1, 28, 28)

# %%
print(x[0].shape)  # 첫 번째 데이터
print(x[1].shape)  # 두 번째 데이터
# Out:
# (1, 28, 28)
# (1, 28, 28)

# %%
# 첫 번째 데이터의 첫 채널의 공간 데이터
x[0, 0]  # 또는 x[0][0]
# Out:
# array([[0.08736639, 0.84321321, 0.77094996, 0.43786657, 0.79480207,
#         0.10884647, 0.67585197, 0.13009952, 0.74723135, 0.31258649,
#         0.48585701, 0.86499038, 0.27915117, 0.11081942, 0.40933076,
#         0.00756667, 0.31128127, 0.75757369, 0.13458714, 0.18210094,
#         0.99810552, 0.91099954, 0.6866449 , 0.12053807, 0.50209917,
#         0.54977606, 0.34340909, 0.43445758],
#        [0.65937738, 0.27584612, 0.85362567, 0.43386406, 0.77722271,
#         0.24436625, 0.42305588, 0.78004169, 0.26722462, 0.26933903,
#         0.10445547, 0.49547134, 0.48527768, 0.51275149, 0.43147052,
#         0.37803702, 0.26500931, 0.5142174 , 0.40677766, 0.39385769,
#         0.3926846 , 0.8660129 , 0.90533655, 0.05398154, 0.8473956 ,
#         0.90562824, 0.33462983, 0.41338978],
#        [0.8193497 , 0.61262762, 0.61722345, 0.1523274 , 0.24885371,
#         0.6961452 , 0.93134653, 0.50825822, 0.42111066, 0.14381382,
# ...

# %% [markdown]
# ### 7.4.2 im2col로 데이터 전개하기
#
# __`im2col`__ : 입력 데이터를 필터링(가중치 계산)하기 좋게 전개하는(펼치는) 함수
#
# <img src='./img/fig 7-17.png' width=400>
#
# - 3차원(배치 안의 데이터 수를 포함하면 4차원) 데이터 $\rightarrow$ 2차원
#
# <br>
#
# <img src='./img/fig 7-18.png' width=400>
#
# - 필터를 적용하는 모든 영역에서 수행하여 앞에서부터 순서대로 한 줄로 펼침
# - 실제 상황에서는 영역이 겹치는 경우가 대부분
#     - 전개한 후의 원소 수가 원래 블록의 원소 수보다 많아짐 $\rightarrow$ 메모리를 더 많이 소비 $\rightarrow$ but 컴퓨터는 행렬 계산 잘해서 OK
#
# <br>
#
# <img src='./img/fig 7-19.png' width=500>
#
# 1. im2col로 입력 데이터를 전개
# 2. 합성곱 계층의 필터(가중치)를 1열로 전개
# 3. 두 행렬의 곱을 계산
# 4. 2차원인 출력 데이터를 4차원으로 변형(reshape)

# %% [markdown]
# ### 7.4.3 합성곱 계층 구현하기
#
# __im2col__(input_data, filter_h, filter_w, stride=1, pad=0)
# - input_data - (데이터 수, 채널 수, 높이, 너비)의 4차원 배열로 이뤄진 입력 데이터
# - filter_h - 필터의 높이
# - filter_w - 필터의 너비
# - stride - 스트라이드
# - pad - 패딩

# %%
import numpy as np
import sys, os
sys.path.append(os.pardir)
from common.util import im2col

x1 = np.random.rand(1, 3, 7, 7)  # (데이터 수, 채널 수, 높이, 너비)
col1 = im2col(x1, 5, 5, stride=1, pad=0)
print(col1.shape)

x2 = np.random.rand(10, 3, 7, 7)  # 데이터 10개
col2 = im2col(x2, 5, 5, stride=1, pad=0)
print(col2.shape)
# Out:
# (9, 75)
# (90, 75)

# %%
class Convolution:
    def __init__(self, W, b, stride=1, pad=0):
        self.W = W
        self.b = b
        self.stride = stride
        self.pad = pad
    
    def forward(self, x):
        FN, C, FH, FW = self.W.shape
        N, C, H, W = x.shape
        out_h = int(1 + (H + 2*self.pad - FH) / self.stride)
        out_w = int(1 + (W + 2*self.pad - FW) / self.stride)
        
        col = im2col(x, FH, FW, self.stride, self.pad)
        col_W = self.W.reshape(FN, -1).T  # 필터 전개
        out = np.dot(col, col_W) + self.b
        
        out = out.reshape(N, out_h, out_w, -1).transpose(0, 3, 1, 2)
        
        return out

# %% [markdown]
# <img src='./img/fig 7-20.png' width=400>

# %% [markdown]
# ### 7.4.4 풀링 계층 구현하기
#
# <img src='./img/fig 7-21.png' width=400>
#
# - 풀링 적용 역역을 채널마다 독립적으로 전개
#
# <br>
#
# <img src='./img/fig 7-22.png' width=500>
#
# 1. 입력 데이터를 전개한다.
# 2. 행별 최댓값을 구한다.
# 3. 적절한 모양으로 성형한다.

# %%
class Pooling:
    def __init__(self, pool_h, pool_w, stride=1, pad=0):
        self.pool_h = pool_h
        self.pool_w = pool_w
        self.stride = stride
        self.pad = pad
        
    def forward(self, x):
        N, C, H, W = x.shape
        out_h = int(1 + (H - self.pool_h) / self.stride)
        out_w = int(1 + (W - self.pool_w) / self.stride)
        
        # 전개 (1)
        col = im2col(x, self.pool_h, self.pool_w, self.stride, self.pad)
        col = col.reshape(-1, self.pool_h*self.pool_w)
        
        # 최댓값 (2)
        out = np.max(col, axis=1)
        
        # 성형 (3)
        out = out.reshape(N, out_h, out_w, C).transpose(0, 3, 1, 2)
        
        return out

# %% [markdown]
# ※ NOTE_
#
# __`np.max`__(x, axis=1) : 입력 x의 1번째 차원의 축마다 최댓값을 구함

# %% [markdown]
# ## 7.5 CNN 구현하기
# P.250

# %% [markdown]
# <img src='./img/fig 7-23.png' width=500>

# %%
class SimpleConvNet:
    def __init__(self, input_dim=(1, 28, 28),
                conv_param={'filter_num':30, 'filter_size':5, 'pad':0, 'stride':1},
                hidden_size=100, output_size=10, weight_init_std=0.01):
        filter_num = conv_param['filter_num']
        filter_size = conv_param['filter_size']
        filter_pad = conv_param['pad']
        filter_stride = conv_param['stride']
        input_size = input_dim[1]
        conv_output_size = (input_size - filter_size + 2*filter_pad) / filter_stride + 1
        pool_output_size = int(filter_num * (conv_output_size/2) * (conv_output_size/2))
        
        
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(filter_num, input_dim[0],
                                                              filter_size, filter_size)
        self.params['b1'] = np.zeros(filter_num)
        self.params['W2'] = weight_init_std * np.random.randn(pool_output_size, hidden_size)
        self.params['b2'] = np.zeros(hidden_size)
        self.params['W3'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b3'] = np.zeros(output_size)
        
        
        self.layers = OrderedDict()
        self.layers['Conv1'] = Convolution(self.params['W1'], self.params['b1'],
                                          conv_params['stride'], conv_params['pad'])
        self.layers['Relu1'] = Relu()
        self.layers['Pool1'] = Pooling(pool_h=2, pool_w=2, stride=2)
        self.layers['Affine1'] = Affine(self.params['W2'], self.params['b2'])
        self.layers['Relu2'] = Relu()
        self.layers['Affine2'] = Affine(self.params['W3'], self.params['b3'])
        
        self.last_layer = SoftmaxWithLoss()
        
        
    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)
        return x
        
        
    def loss(self, x, t):
        y = self.predict(x)
        return self.last_layer.forward(y, t)        
        
        
    def gradient(self, x, t):
        # 순전파
        self.loss(x, t)
        
        # 역전파
        dout = 1
        dout = self.last_layer.backward(dout)
        
        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)
            
        # 결과 저장
        grads = {}
        grads['W1'] = self.layers['Conv1'].dW
        grads['b1'] = self.layers['Conv1'].db
        grads['W2'] = self.layers['Affine1'].dW
        grads['b2'] = self.layers['Affine1'].db
        grads['W3'] = self.layers['Affine2'].dW
        grads['b3'] = self.layers['Affine2'].db
        
        return grads

# %% [markdown]
# ## 7.6 CNN 시각화하기
# P.254

# %% [markdown]
# ### 7.6.1 1번째 층의 가중치 시각화하기
#
# <img src='./img/fig 7-24.png' width=500>
#
# - 학습 전 필터 - 무작위로 초기화, 규칙성 없음
# - 학습 후 필터 - 규칙성 있음
#
# <br>
#
# <img src='./img/fig 7-25.png' width=500>
#
# - __에지__ : 색상이 바뀐 경계선
# - __블롭__ : 국소적으로 덩어리진 영역

# %% [markdown]
# ### 7.6.2 층 깊이에 따른 추출 정보 변화
#
# <img src='./img/fig 7-26.png' width=600>
#
# - 층이 깊어질수록 더 복잡하고 추상화된 정보가 추출됨
# >뉴런이 반응하는 대상이 단순한 모양에서 '고급' 정보로 변화

# %% [markdown]
# ## 7.7 대표적인 CNN
# P.257

# %% [markdown]
# ### 7.7.1 LeNet
#
# <img src='./img/fig 7-27.png' width=600>
#
# - 손글씨 숫자를 인식하는 네트워크
# - 활성화 함수로 __시그모이드 함수__를 사용함
# - __서브샘플링__을 하여 중간 데이터의 크기를 줄임

# %% [markdown]
# ### 7.7.2 AlexNet
#
# <img src='./img/fig 7-28.png' width=600>
#
# - 활성화 함수로 __ReLU__를 사용함
# - __최대 풀링__
# - LRN이라는 국소적 정규화를 실시하는 계층을 이용함
# - 드롭아웃을 사용함
#
# >빅테이터와 GPU의 발달
